# %%
import numpy as np
import gym_minatar

# Generic replay buffer for standard gym tasks
class TaskBuffer(object):
    def __init__(self, state_shape, sf_dim, buffer_size, device):
        self.max_size = int(buffer_size)
        self.device = device

        self.ptr = 0
        self.crt_size = 0

        self.state = np.zeros((self.max_size, *state_shape))
        self.action = np.zeros((self.max_size, 1))
        self.next_state = np.zeros((self.max_size, *state_shape))
        # self.next_state = np.array(self.state)
        self.reward = np.zeros((self.max_size, 1))
        self.not_done = np.zeros((self.max_size, 1))
        self.task = np.zeros((self.max_size, sf_dim))


    def add(self, state, action, next_state, reward, done, task):
        self.state[self.ptr] = state
        self.action[self.ptr] = action
        self.next_state[self.ptr] = next_state
        self.reward[self.ptr] = reward
        self.not_done[self.ptr] = 1. - done
        self.task[self.ptr] = task

        self.ptr = (self.ptr + 1) % self.max_size
        self.crt_size = min(self.crt_size + 1, self.max_size)

    def sample(self, batch_size=32):
        ind = np.random.randint(0, self.crt_size, size=batch_size)
        return (
            torch.FloatTensor(self.state[ind]).to(self.device),
            torch.LongTensor(self.action[ind]).to(self.device),
            torch.FloatTensor(self.next_state[ind]).to(self.device),
            torch.FloatTensor(self.reward[ind]).to(self.device),
            torch.FloatTensor(self.not_done[ind]).to(self.device),
            torch.FloatTensor(self.task[ind]).to(self.device),
        )


    def save(self, save_folder):
        np.save(f"{save_folder}_state.npy", self.state[:self.crt_size])
        np.save(f"{save_folder}_action.npy", self.action[:self.crt_size])
        np.save(f"{save_folder}_next_state.npy", self.next_state[:self.crt_size])
        np.save(f"{save_folder}_reward.npy", self.reward[:self.crt_size])
        np.save(f"{save_folder}_not_done.npy", self.not_done[:self.crt_size])
        np.save(f"{save_folder}_task.npy", self.task[:self.crt_size])
        np.save(f"{save_folder}_ptr.npy", self.ptr)


    def load(self, save_folder, size=-1):
        reward_buffer = np.load(f"{save_folder}_reward.npy")

        # Adjust crt_size if we're using a custom size
        size = min(int(size), self.max_size) if size > 0 else self.max_size
        self.crt_size = min(reward_buffer.shape[0], size)

        self.state[:self.crt_size] = np.load(f"{save_folder}_state.npy")[:self.crt_size]
        self.action[:self.crt_size] = np.load(f"{save_folder}_action.npy")[:self.crt_size]
        self.next_state[:self.crt_size] = np.load(f"{save_folder}_next_state.npy")[:self.crt_size]
        self.reward[:self.crt_size] = reward_buffer[:self.crt_size]
        self.not_done[:self.crt_size] = np.load(f"{save_folder}_not_done.npy")[:self.crt_size]
        self.task[:self.crt_size] = np.load(f"{save_folder}_task.npy")[:self.crt_size]
        print(f"Replay Buffer loaded with {self.crt_size} elements.")

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

import copy
from tqdm import tqdm
from dqn import DQN, Phi, Critic
import gym

class ConvEncoder(nn.Module):
    def __init__(
        self,
        state_shape, # ex (4, 84, 84), (3, 7, 7)
        latent_dim,
    ):
        super().__init__()
        
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.state_shape = state_shape
        self.latent_dim = latent_dim
        
        def make_dummy_conv():
            encoder = nn.Linear(self.state_shape[0], self.latent_dim).to(device)
            return encoder
            
        def make_conv():
            conv = nn.Sequential(nn.Conv2d(state_shape[0], 32, 3, stride=1),
                                     nn.ReLU(), nn.Conv2d(32, 16, 3, stride=1),
                                     nn.ReLU()).to(device)
            sample = torch.zeros(1, *state_shape).to(device)
            size = torch.flatten(conv(sample)).shape[-1]
            encoder = nn.Sequential(conv, nn.Flatten(), nn.Linear(size, self.latent_dim), nn.ReLU()).to(device)
            return encoder
        
        if len(self.state_shape) < 2:
            self.encoder = make_dummy_conv()
        else:
            self.encoder = make_conv()
            
    def forward(self, state):
        return self.encoder(state)
    

class RMS(object):
    """running mean and std """
    def __init__(self, device, epsilon=1e-4, shape=(1,)):
        self.M = torch.zeros(shape).to(device)
        self.S = torch.ones(shape).to(device)
        self.n = epsilon

    def __call__(self, x):
        bs = x.size(0)
        delta = torch.mean(x, dim=0) - self.M
        new_M = self.M + delta * bs / (self.n + bs)
        new_S = (self.S * self.n + torch.var(x, dim=0) * bs +
                 torch.square(delta) * self.n * bs /
                 (self.n + bs)) / (self.n + bs)

        self.M = new_M
        self.S = new_S
        self.n += bs

        return self.M, self.S
    
class PBE(object):
    """particle-based entropy based on knn normalized by running mean """
    def __init__(self, rms, knn_clip, knn_k, knn_avg, knn_rms, device):
        self.rms = rms
        self.knn_rms = knn_rms
        self.knn_k = knn_k
        self.knn_avg = knn_avg
        self.knn_clip = knn_clip
        self.device = device

    def __call__(self, rep):
        source = target = rep
        b1, b2 = source.size(0), target.size(0)
        # (b1, 1, c) - (1, b2, c) -> (b1, 1, c) - (1, b2, c) -> (b1, b2, c) -> (b1, b2)
        sim_matrix = torch.norm(source[:, None, :].view(b1, 1, -1) -
                                target[None, :, :].view(1, b2, -1),
                                dim=-1,
                                p=2)
        reward, _ = sim_matrix.topk(self.knn_k,
                                    dim=1,
                                    largest=False,
                                    sorted=True)  # (b1, k)
        if not self.knn_avg:  # only keep k-th nearest neighbor
            reward = reward[:, -1]
            reward = reward.reshape(-1, 1)  # (b1, 1)
            reward /= self.rms(reward)[0] if self.knn_rms else 1.0
            reward = torch.maximum(
                reward - self.knn_clip,
                torch.zeros_like(reward).to(self.device)
            ) if self.knn_clip >= 0.0 else reward  # (b1, 1)
        else:  # average over all k nearest neighbors
            reward = reward.reshape(-1, 1)  # (b1 * k, 1)
            reward /= self.rms(reward)[0] if self.knn_rms else 1.0
            reward = torch.maximum(
                reward - self.knn_clip,
                torch.zeros_like(reward).to(
                    self.device)) if self.knn_clip >= 0.0 else reward
            reward = reward.reshape((b1, self.knn_k))  # (b1, k)
            reward = reward.mean(dim=1, keepdim=True)  # (b1, 1)
        reward = torch.log(reward + 1.0)
        return reward
    
    
class IdentityPhi(nn.Module):
    def __init__(
        self,
        latent_dim,
        hidden_dim,
        sf_dim,
    ):
        super().__init__()
        self.fc1 = nn.Linear(1, 1)
    
    def forward(self, latent, norm=True):
        return F.normalize(latent, dim=-1)
    
class MiniAtarWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super().__init__(env)
        # self.observation_space = gym.spaces.Box(low=np.zeros((1, 13, 13)), high=np.ones((1, 13, 13)), dtype=np.uint8)
        # self.observation_space = gym.spaces.Box(low=np.zeros((7, 10, 10)), high=np.ones((7, 10, 10)), dtype=np.float32)
        size = env.observation_space.shape[0]
        self.size = size
        low = env.observation_space.low.reshape((size, 10, 10))
        high = env.observation_space.high.reshape((size, 10, 10))
        dtype = env.observation_space.dtype
        self.observation_space = gym.spaces.Box(low=low, high=high, dtype=dtype)
    
    def observation(self, state):
        return state.reshape((self.size, 10, 10))

class GridAPS(DQN):
    def __init__(
        self,
        env,
        conv=True,
        discount=0.99,
        lr_critic=1e-4,
        lr_encoder=1e-4, 
        latent_dim=256,
        hidden_dim=256,
        initial_eps=1,
        end_eps=0.1,
        eval_eps=0.1,
        pretrain_eps=1,
        eps_decay_period=int(2e4),
        target_update_frequency=200,
        double_q=False,
        # the following are variables for APS
        sf_dim=169,
        lr_phi=1e-4,
        lr_task=1e-4,
        update_task_frequency=5,
        knn_k=12,
        knn_rms=True,
        knn_avg=True,
        knn_clip=1e-4,
    ):
        # for APS 
        self.sf_dim = sf_dim
        self.lr_phi = lr_phi
        self.lr_task = lr_task
        self.update_task_frequency = update_task_frequency
        self.knn_k = knn_k
        self.knn_rms = knn_rms
        self.knn_avg = knn_avg
        self.knn_clip = knn_clip
        self.temp_task = None # temp tasks are set through function : set_task
        
        super().__init__(
            env=MiniAtarWrapper(env),
            conv=conv,
            discount=discount,
            lr_critic=lr_critic,
            lr_encoder=lr_encoder,
            latent_dim=latent_dim,
            hidden_dim=hidden_dim,
            initial_eps=initial_eps,
            end_eps=end_eps,
            eval_eps=eval_eps,
            pretrain_eps=pretrain_eps,
            eps_decay_period=eps_decay_period,
            target_update_frequency=target_update_frequency,
            double_q=double_q,
        )
        
    def _make_alias(self):
        self.SF1 = self.critic.get_SF1
        self.SF = self.critic.get_SFs
        self.SF1_target = self.critic_target.get_SF1
        self.SF_target = self.critic_target.get_SFs
        
        # to get Q's, one need 'task' (a k-dim vector)
        self.Q1 = self.critic.get_Q1
        self.Q = self.critic.get_Qs
        self.Q1_target = self.critic_target.get_Q1
        self.Q_target = self.critic_target.get_Qs
        
    def _define_networks(self):
        self.encoder = ConvEncoder(
            state_shape=self.state_shape,
            latent_dim=self.latent_dim,
        )
        
        self.phi = Phi(
            latent_dim=self.latent_dim,
            hidden_dim=self.hidden_dim,
            sf_dim=self.sf_dim,
        )

        
        self.critic = Critic(
            latent_dim=self.latent_dim + self.sf_dim, # input is cat([latent, task])
            hidden_dim=self.hidden_dim, 
            num_actions=self.num_actions,
            sf_dim=self.sf_dim
        )
        self.critic_target = copy.deepcopy(self.critic)
        
        self.RMS = RMS(self.device)
        self.PBE = PBE(
            rms=self.RMS, 
            knn_clip=self.knn_clip, 
            knn_k=self.knn_k, 
            knn_avg=self.knn_avg, 
            knn_rms=self.knn_rms,
            device=self.device
        )
        
        self.encoder_opt = torch.optim.Adam(self.encoder.parameters(), lr=self.lr_encoder)
        self.phi_opt = torch.optim.Adam(self.phi.parameters(), lr=self.lr_phi)
        self.critic_opt = torch.optim.Adam(self.critic.parameters(), lr=self.lr_critic)
        
        self.task_learned = True
        self.task = torch.ones((1, self.sf_dim), requires_grad=True, device=self.device) # task is only for RL phase (supervised learning phase)
        self.task_opt = torch.optim.Adam([self.task], lr=self.lr_task)
        
    def intrinsic_reward(self, task, next_latent):
        # maxent reward
        with torch.no_grad():
            state_representation = self.phi(next_latent, norm=False)
        bonus = self.PBE(state_representation)
        ent_bonus = bonus.view(-1, 1)

        # successor feature reward
        state_representation = state_representation / torch.norm(state_representation, dim=1, keepdim=True)
        sf_reward = torch.einsum("bi,bi->b", task, state_representation).reshape(-1, 1)

        return ent_bonus, sf_reward
    
    def maybe_set_task(self, fine_tune):
        if fine_tune:
            return self.task
        elif (self.iterations + 1) % self.update_task_frequency:
            return self.set_task()
        
        return self.temp_task
    
    def set_task(self):
        task = torch.randn(self.sf_dim).to(self.device)
        task = task / torch.norm(task)
        self.temp_task = task
        return task
    
    def visualize_representation(self, state):
        # state needs to be a numpy array
        state = torch.from_numpy(state).unsqueeze(0).to(self.device)
        out = self.phi(self.encoder(state))
        return out.cpu().data.numpy()
    
    def make_replay_buffer(self, buffer_size=int(3e5)):
        return TaskBuffer(self.state_shape, self.sf_dim, buffer_size, self.device)
        
    def select_action(self, state, task, eval=False, pretrain=True):
        # this function affects evaluation funciton
        if eval: # if eval, we don't care if we are pretraining or not
            eps = self.eval_eps
        elif pretrain: # if pretrain, we use pretrain eps
            eps = self.pretrain_eps
        else:
            eps = max(self.slope * self.iterations + self.initial_eps, self.end_eps)

        # Select action according to policy with probability (1-eps)
        # otherwise, select random action
        if np.random.uniform(0,1) > eps:
            with torch.no_grad():
                state = torch.FloatTensor(state).reshape(self.state_shape).unsqueeze(0).to(self.device)                    
                if type(task) == np.ndarray:
                    task = torch.from_numpy(task).to(self.device)
                task = task.float().view(1, task.shape[-1])
                
                latent = self.encoder(state)
                
                # cat latent and task for universal successor feature
                latent = torch.cat([latent, task], dim=1)
                return int(self.Q1(latent, task).argmax(1))
        else:
            return np.random.randint(self.num_actions)
    
    def train(self, replay_buffer, batch_size=128, fine_tune=False):
        state, action, next_state, reward, not_done, task = replay_buffer.sample(batch_size=batch_size)
        
        latent = self.encoder(state)
        next_latent = self.encoder(next_state)
        
        # calculate the adjusted reward
        if fine_tune:
            reward = reward # even when we are finetuning, use the task got from the replay_buffer
            # task = self.task.repeat(batch_size, 1) # use the regressed task
        else:
            with torch.no_grad():
                ent_bonus, sf_reward = self.intrinsic_reward(task, next_latent)
                aps_reward = ent_bonus + sf_reward
                reward = aps_reward
            # calculte Phi-loss
            phi_loss = - torch.einsum("bi,bi->b", self.phi(next_latent), task).mean()
            # update Phi and Encoder
            self.encoder_opt.zero_grad()
            self.phi_opt.zero_grad()
            phi_loss.backward()
            self.encoder_opt.step()
            self.phi_opt.step()
        
        
        # cat latent and task, for universal SF approximator
        # we don't update encoder based on Q-loss
        latent = torch.cat([latent, task], dim=1).detach()
        next_latent = torch.cat([next_latent, task], dim=1).detach()
        
        # calculate Q-loss
        with torch.no_grad():
            next_action = self.Q1(next_latent, task).argmax(1, keepdim=True)
            if self.double_q:
                target_Q1, target_Q2 = self.Q_target(next_latent, task)
                target_Q1, target_Q2 = (
                    target_Q1.gather(1, next_action).view(-1, 1),
                    target_Q2.gather(1, next_action).view(-1, 1)
                )
                target_Q = torch.min(target_Q1, target_Q2)
            else:
                target_Q = self.Q1_target(next_latent, task).gather(1, next_action).view(-1, 1)
            
            # print(f'reward : {reward}, not_done : {not_done}, next_action :{next_action}, target_Q : {target_Q}')
            target_Q = reward + not_done * self.discount * target_Q
            
        
        if self.double_q:
            Q1, Q2 = self.Q(latent, task)
            Q1, Q2 = (
                Q1.gather(1, action).view(-1, 1),
                Q2.gather(1, action).view(-1, 1)
            )
            
            Q_loss = F.mse_loss(Q1, target_Q) + F.mse_loss(Q2, target_Q)
        else:
            Q = self.Q1(latent, task).gather(1, action).view(-1, 1)
            Q_loss = F.mse_loss(Q, target_Q)
        
        # update Q-networks
        # print(f'Q-loss : {Q_loss}, Q : {Q}, Q_target : {target_Q}')
        # print(Q_loss.mean())
        self.critic_opt.zero_grad()
        Q_loss.backward()
        self.critic_opt.step()
        
        # train the task
        # self.regress_task(replay_buffer, 256, 1)
        self.maybe_regress_task(replay_buffer, 256, 1)
        
        # update target network
        self.copy_target_update()
        
    def maybe_regress_task(self, replay_buffer, batch_size, epoch_size=1):
        if replay_buffer.crt_size > 4096 and self.iterations % self.update_task_frequency == 0:
            self.regress_task(replay_buffer, batch_size, epoch_size)
        
    def regress_task(self, replay_buffer, batch_size=32, epoch_size=1):
        # there are two options, one is using gradient descent, the other is using torch.linalg.lstsq
        self.task_learned = True
        for epoch in range(epoch_size):
            state, action, next_state, reward, *_ = replay_buffer.sample(batch_size=batch_size)
            with torch.no_grad():
                next_latent = self.encoder(next_state)
                # next_latent = self.encoder(state)
                representation = self.phi(next_latent)
                
            # estimate the reward
            estimated_reward = torch.einsum("bi,bi->b", representation, self.task.repeat(batch_size, 1)) # 256 by 169, 1 by 169
            
            # update the task
            task_loss = F.mse_loss(reward, estimated_reward)
            self.task_opt.zero_grad()
            task_loss.backward()
            self.task_opt.step()
                
    def learn(self, replay_buffer, step_size, learning_start=int(1e4), batch_size=32, fine_tune=False, log_freq=int(1e3)):
        if replay_buffer is None:
            replay_buffer = self.make_replay_buffer()
            
        state = self.env.reset()
        episodic_return = 0
        episode_length = 0
        episode_num = 0
        task = self.set_task()
        evaluations = []
        
        for step in tqdm(range(step_size)):
            if fine_tune:
                self.iterations += 1
            # pick action and transit in the env
            task = self.maybe_set_task(fine_tune)
            if step < learning_start:
                action = self.env.action_space.sample()
            else:
                action = self.select_action(state, task, eval=False, pretrain=(not fine_tune))
            next_state, reward, done, info = self.env.step(action)
            
            # add the experience into the buffer
            replay_buffer.add(state, action, next_state, reward, done, task.cpu().data.numpy())
            if replay_buffer.crt_size > learning_start:
                self.train(replay_buffer, batch_size=batch_size, fine_tune=fine_tune)
            
            # update iterative values
            state = next_state
            episodic_return += reward
            episode_length += 1
            
            # maybe evaluate
            if fine_tune and (step + 1) % log_freq == 0:
                evaluations.append(self.evaluate(fine_tune))
            
            # check if the episode ends
            if done:
                if fine_tune:
                    print(f"====== Total T: {step+1} Episode Num: {episode_num+1} Episode_Length T: {episode_length} Return: {episodic_return:.3f} ======")
                episode_num += 1
                state = self.env.reset()
                episodic_return = 0
                episode_length = 0
                
        return evaluations
    
    def evaluate(self, fine_tune, seed=0, eval_episodes=10):
        eval_env = copy.deepcopy(self.env)
        eval_env.seed(seed + 100)

        avg_reward = 0.
        task = self.maybe_set_task(fine_tune)
        for _ in range(eval_episodes):
            state, done = eval_env.reset(), False
            while not done:
                action = self.select_action(np.array(state), task, eval=True)
                state, reward, done, _ = eval_env.step(action)
                avg_reward += reward

        avg_reward /= eval_episodes

        print("---------------------------------------")
        print(f"Evaluation over {eval_episodes} episodes: {avg_reward:.3f}")
        print("---------------------------------------")
        return avg_reward

# %%
env.observation_space.shape
# Out:
# (10, 10, 10)

# %%
import gym_minatar
# env = FourRooms(config=2, layout='4rooms')
env = gym.make('Seaquest-MinAtar-v0')
aps = GridAPS(
    env, 
    conv=False,
    pretrain_eps=0.5,
    eps_decay_period=int(2e5),
    double_q=False,
    sf_dim=5,
    latent_dim=256,
    update_task_frequency=5,
)

# %%
aps.encoder
# Out:
# ConvEncoder(
#   (encoder): Sequential(
#     (0): Sequential(
#       (0): Conv2d(10, 16, kernel_size=(3, 3), stride=(1, 1))
#       (1): ReLU()
#       (2): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1))
#       (3): ReLU()
#     )
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=576, out_features=256, bias=True)
#     (3): ReLU()
#   )
# )

# %%
replay_buffer = aps.make_replay_buffer()
aps.learn(replay_buffer, step_size=int(1e6), batch_size=256, fine_tune=False, log_freq=int(1e4))
# Out:
#  42%|████▏     | 421653/1000000 [2:53:12<3:57:34, 40.57it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_54377/3122077900.py in <module>
#       1 replay_buffer = aps.make_replay_buffer()
# ----> 2 aps.learn(replay_buffer, step_size=int(1e6), batch_size=256, fine_tune=False, log_freq=int(1e4))
#
# /tmp/ipykernel_54377/2005752785.py in learn(self, replay_buffer, step_size, learning_start, batch_size, fine_tune, log_freq)
#     424             replay_buffer.add(state, action, next_state, reward, done, task.cpu().data.numpy())
#     425             if replay_buffer.crt_size > learning_start:
# --> 426                 self.train(replay_buffer, batch_size=batch_size, fine_tune=fine_tune)
#     427
#     428             # update iterative values
#
# /tmp/ipykernel_54377/2005752785.py in train(self, replay_buffer, batch_size, fine_tune)
#     304
#     305     def train(self, replay_buffer, batch_size=128, fine_tune=False):
# --> 306         state, action, next_state, reward, not_done, task = replay_buffer.sample(batch_size=batch_size)
#     307
#     308         latent = self.encoder(state)
#
# /tmp/ipykernel_54377/2369808480.py in sample(self, batch_size)
#      34         ind = np.random.randint(0, self.crt_size, size=batch_size)
#      35         return (
# ---> 36             torch.FloatTensor(self.state[ind]).to(self.device),
#      37             torch.LongTensor(self.action[ind]).to(self.device),
#      38             torch.FloatTensor(self.next_state[ind]).to(self.device),
#
# KeyboardInterrupt:

# %%
ft_rp = aps.make_replay_buffer()
evaluations = aps.learn(
    ft_rp,
    step_size=int(1e6),
    learning_start=int(1e4),
    batch_size=32,
    fine_tune=True
)
# Out:
#   0%|          | 791/1000000 [00:00<02:06, 7901.30it/s]
# ====== Total T: 17 Episode Num: 1 Episode_Length T: 17 Return: 0.000 ======
# ====== Total T: 21 Episode Num: 2 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 23 Episode Num: 3 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 211 Episode Num: 4 Episode_Length T: 188 Return: 1.000 ======
# ====== Total T: 268 Episode Num: 5 Episode_Length T: 57 Return: 1.000 ======
# ====== Total T: 322 Episode Num: 6 Episode_Length T: 54 Return: 0.000 ======
# ====== Total T: 363 Episode Num: 7 Episode_Length T: 41 Return: 0.000 ======
# ====== Total T: 386 Episode Num: 8 Episode_Length T: 23 Return: 0.000 ======
# ====== Total T: 390 Episode Num: 9 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 434 Episode Num: 10 Episode_Length T: 44 Return: 0.000 ======
# ====== Total T: 452 Episode Num: 11 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 458 Episode Num: 12 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 499 Episode Num: 13 Episode_Length T: 41 Return: 0.000 ======
# ====== Total T: 518 Episode Num: 14 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 550 Episode Num: 15 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 557 Episode Num: 16 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 561 Episode Num: 17 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 590 Episode Num: 18 Episode_Length T: 29 Return: 0.000 ======
# ====== Total T: 609 Episode Num: 19 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 645 Episode Num: 20 Episode_Length T: 36 Return: 0.000 ======
# ====== Total T: 649 Episode Num: 21 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 684 Episode Num: 22 Episode_Length T: 35 Return: 0.000 ======
# ====== Total T: 708 Episode Num: 23 Episode_Length T: 24 Return: 0.000 ======
# ====== Total T: 830 Episode Num: 24 Episode_Length T: 122 Return: 1.000 ======
# ====== Total T: 847 Episode Num: 25 Episode_Length T: 17 Return: 0.000 ======
# ====== Total T: 867 Episode Num: 26 Episode_Length T: 20 Return: 0.000 ======
# ====== Total T: 944 Episode Num: 27 Episode_Length T: 77 Return: 1.000 ======
# ====== Total T: 947 Episode Num: 28 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 957 Episode Num: 29 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 985 Episode Num: 30 Episode_Length T: 28 Return: 0.000 ======
# ====== Total T: 991 Episode Num: 31 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 998 Episode Num: 32 Episode_Length T: 7 Return: 0.000 ======
#   0%|          | 1582/1000000 [00:01<15:02, 1106.57it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.500
# ---------------------------------------
# ====== Total T: 1046 Episode Num: 33 Episode_Length T: 48 Return: 0.000 ======
# ====== Total T: 1070 Episode Num: 34 Episode_Length T: 24 Return: 0.000 ======
# ====== Total T: 1082 Episode Num: 35 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 1093 Episode Num: 36 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 1107 Episode Num: 37 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 1116 Episode Num: 38 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 1130 Episode Num: 39 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 1156 Episode Num: 40 Episode_Length T: 26 Return: 0.000 ======
# ====== Total T: 1163 Episode Num: 41 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 1175 Episode Num: 42 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 1181 Episode Num: 43 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 1215 Episode Num: 44 Episode_Length T: 34 Return: 0.000 ======
# ====== Total T: 1228 Episode Num: 45 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 1284 Episode Num: 46 Episode_Length T: 56 Return: 0.000 ======
# ====== Total T: 1307 Episode Num: 47 Episode_Length T: 23 Return: 0.000 ======
# ====== Total T: 1329 Episode Num: 48 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 1347 Episode Num: 49 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 1361 Episode Num: 50 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 1366 Episode Num: 51 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 1409 Episode Num: 52 Episode_Length T: 43 Return: 0.000 ======
# ====== Total T: 1412 Episode Num: 53 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 1492 Episode Num: 54 Episode_Length T: 80 Return: 0.000 ======
# ====== Total T: 1681 Episode Num: 55 Episode_Length T: 189 Return: 0.000 ======
# ====== Total T: 1762 Episode Num: 56 Episode_Length T: 81 Return: 0.000 ======
# ====== Total T: 1769 Episode Num: 57 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 1773 Episode Num: 58 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 1791 Episode Num: 59 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 1830 Episode Num: 60 Episode_Length T: 39 Return: 0.000 ======
# ====== Total T: 1838 Episode Num: 61 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 1949 Episode Num: 62 Episode_Length T: 111 Return: 0.000 ======
# ====== Total T: 1964 Episode Num: 63 Episode_Length T: 15 Return: 0.000 ======
#   0%|          | 2772/1000000 [00:02<13:43, 1210.66it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.100
# ---------------------------------------
# ====== Total T: 2012 Episode Num: 64 Episode_Length T: 48 Return: 0.000 ======
# ====== Total T: 2044 Episode Num: 65 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 2054 Episode Num: 66 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 2073 Episode Num: 67 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 2099 Episode Num: 68 Episode_Length T: 26 Return: 0.000 ======
# ====== Total T: 2168 Episode Num: 69 Episode_Length T: 69 Return: 0.000 ======
# ====== Total T: 2215 Episode Num: 70 Episode_Length T: 47 Return: 0.000 ======
# ====== Total T: 2287 Episode Num: 71 Episode_Length T: 72 Return: 0.000 ======
# ====== Total T: 2310 Episode Num: 72 Episode_Length T: 23 Return: 0.000 ======
# ====== Total T: 2512 Episode Num: 73 Episode_Length T: 202 Return: 3.000 ======
# ====== Total T: 2539 Episode Num: 74 Episode_Length T: 27 Return: 1.000 ======
# ====== Total T: 2694 Episode Num: 75 Episode_Length T: 155 Return: 1.000 ======
# ====== Total T: 2710 Episode Num: 76 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 2715 Episode Num: 77 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 2724 Episode Num: 78 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 2729 Episode Num: 79 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 2737 Episode Num: 80 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 2765 Episode Num: 81 Episode_Length T: 28 Return: 0.000 ======
# ====== Total T: 2772 Episode Num: 82 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 2777 Episode Num: 83 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 2783 Episode Num: 84 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 2798 Episode Num: 85 Episode_Length T: 15 Return: 0.000 ======
# ====== Total T: 2803 Episode Num: 86 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 2808 Episode Num: 87 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 2810 Episode Num: 88 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 2812 Episode Num: 89 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 2829 Episode Num: 90 Episode_Length T: 17 Return: 0.000 ======
# ====== Total T: 2834 Episode Num: 91 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 2856 Episode Num: 92 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 2865 Episode Num: 93 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 2911 Episode Num: 94 Episode_Length T: 46 Return: 0.000 ======
# ====== Total T: 2925 Episode Num: 95 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 2938 Episode Num: 96 Episode_Length T: 13 Return: 0.000 ======
#   0%|          | 3995/1000000 [00:03<13:13, 1255.95it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.300
# ---------------------------------------
# ====== Total T: 3012 Episode Num: 97 Episode_Length T: 74 Return: 0.000 ======
# ====== Total T: 3054 Episode Num: 98 Episode_Length T: 42 Return: 0.000 ======
# ====== Total T: 3094 Episode Num: 99 Episode_Length T: 40 Return: 0.000 ======
# ====== Total T: 3103 Episode Num: 100 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 3203 Episode Num: 101 Episode_Length T: 100 Return: 0.000 ======
# ====== Total T: 3215 Episode Num: 102 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 3239 Episode Num: 103 Episode_Length T: 24 Return: 0.000 ======
# ====== Total T: 3241 Episode Num: 104 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 3252 Episode Num: 105 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 3433 Episode Num: 106 Episode_Length T: 181 Return: 1.000 ======
# ====== Total T: 3446 Episode Num: 107 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 3487 Episode Num: 108 Episode_Length T: 41 Return: 0.000 ======
# ====== Total T: 3516 Episode Num: 109 Episode_Length T: 29 Return: 0.000 ======
# ====== Total T: 3542 Episode Num: 110 Episode_Length T: 26 Return: 0.000 ======
# ====== Total T: 3558 Episode Num: 111 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 3560 Episode Num: 112 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 3579 Episode Num: 113 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 3677 Episode Num: 114 Episode_Length T: 98 Return: 0.000 ======
# ====== Total T: 3720 Episode Num: 115 Episode_Length T: 43 Return: 0.000 ======
# ====== Total T: 3729 Episode Num: 116 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 3766 Episode Num: 117 Episode_Length T: 37 Return: 0.000 ======
# ====== Total T: 3788 Episode Num: 118 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 3843 Episode Num: 119 Episode_Length T: 55 Return: 0.000 ======
# ====== Total T: 3853 Episode Num: 120 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 3862 Episode Num: 121 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 3866 Episode Num: 122 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 3868 Episode Num: 123 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 3884 Episode Num: 124 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 3917 Episode Num: 125 Episode_Length T: 33 Return: 0.000 ======
# ====== Total T: 3933 Episode Num: 126 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 3951 Episode Num: 127 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 3974 Episode Num: 128 Episode_Length T: 23 Return: 0.000 ======
#   0%|          | 4457/1000000 [00:04<18:14, 909.38it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.100
# ---------------------------------------
# ====== Total T: 4029 Episode Num: 129 Episode_Length T: 55 Return: 0.000 ======
# ====== Total T: 4032 Episode Num: 130 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 4038 Episode Num: 131 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 4070 Episode Num: 132 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 4101 Episode Num: 133 Episode_Length T: 31 Return: 0.000 ======
# ====== Total T: 4135 Episode Num: 134 Episode_Length T: 34 Return: 0.000 ======
# ====== Total T: 4143 Episode Num: 135 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 4188 Episode Num: 136 Episode_Length T: 45 Return: 0.000 ======
# ====== Total T: 4205 Episode Num: 137 Episode_Length T: 17 Return: 0.000 ======
# ====== Total T: 4413 Episode Num: 138 Episode_Length T: 208 Return: 0.000 ======
# ====== Total T: 4430 Episode Num: 139 Episode_Length T: 17 Return: 0.000 ======
# ====== Total T: 4456 Episode Num: 140 Episode_Length T: 26 Return: 0.000 ======
# ====== Total T: 4469 Episode Num: 141 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 4476 Episode Num: 142 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 4503 Episode Num: 143 Episode_Length T: 27 Return: 0.000 ======
# ====== Total T: 4523 Episode Num: 144 Episode_Length T: 20 Return: 0.000 ======
# ====== Total T: 4597 Episode Num: 145 Episode_Length T: 74 Return: 1.000 ======
# ====== Total T: 4618 Episode Num: 146 Episode_Length T: 21 Return: 0.000 ======
# ====== Total T: 4630 Episode Num: 147 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 4634 Episode Num: 148 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 4645 Episode Num: 149 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 4685 Episode Num: 150 Episode_Length T: 40 Return: 0.000 ======
# ====== Total T: 4705 Episode Num: 151 Episode_Length T: 20 Return: 0.000 ======
# ====== Total T: 4719 Episode Num: 152 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 4732 Episode Num: 153 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 4739 Episode Num: 154 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 4785 Episode Num: 155 Episode_Length T: 46 Return: 0.000 ======
# ====== Total T: 4793 Episode Num: 156 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 4844 Episode Num: 157 Episode_Length T: 51 Return: 0.000 ======
# ====== Total T: 4847 Episode Num: 158 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 4878 Episode Num: 159 Episode_Length T: 31 Return: 0.000 ======
# ====== Total T: 4884 Episode Num: 160 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 4888 Episode Num: 161 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 4931 Episode Num: 162 Episode_Length T: 43 Return: 0.000 ======
# ====== Total T: 4940 Episode Num: 163 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 4953 Episode Num: 164 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 4962 Episode Num: 165 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 4967 Episode Num: 166 Episode_Length T: 5 Return: 0.000 ======
#   1%|          | 5770/1000000 [00:05<14:33, 1138.20it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.600
# ---------------------------------------
# ====== Total T: 5117 Episode Num: 167 Episode_Length T: 150 Return: 1.000 ======
# ====== Total T: 5121 Episode Num: 168 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 5143 Episode Num: 169 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 5189 Episode Num: 170 Episode_Length T: 46 Return: 0.000 ======
# ====== Total T: 5210 Episode Num: 171 Episode_Length T: 21 Return: 0.000 ======
# ====== Total T: 5248 Episode Num: 172 Episode_Length T: 38 Return: 0.000 ======
# ====== Total T: 5251 Episode Num: 173 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 5257 Episode Num: 174 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 5275 Episode Num: 175 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 5310 Episode Num: 176 Episode_Length T: 35 Return: 0.000 ======
# ====== Total T: 5316 Episode Num: 177 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 5343 Episode Num: 178 Episode_Length T: 27 Return: 0.000 ======
# ====== Total T: 5357 Episode Num: 179 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 5363 Episode Num: 180 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 5370 Episode Num: 181 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 5375 Episode Num: 182 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 5377 Episode Num: 183 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 5392 Episode Num: 184 Episode_Length T: 15 Return: 0.000 ======
# ====== Total T: 5410 Episode Num: 185 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 5429 Episode Num: 186 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 5437 Episode Num: 187 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 5669 Episode Num: 188 Episode_Length T: 232 Return: 1.000 ======
# ====== Total T: 5699 Episode Num: 189 Episode_Length T: 30 Return: 0.000 ======
# ====== Total T: 5707 Episode Num: 190 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 5717 Episode Num: 191 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 5733 Episode Num: 192 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 5897 Episode Num: 193 Episode_Length T: 164 Return: 1.000 ======
# ====== Total T: 5901 Episode Num: 194 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 5918 Episode Num: 195 Episode_Length T: 17 Return: 0.000 ======
#   1%|          | 6955/1000000 [00:06<14:39, 1129.28it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.900
# ---------------------------------------
# ====== Total T: 6005 Episode Num: 196 Episode_Length T: 87 Return: 0.000 ======
# ====== Total T: 6017 Episode Num: 197 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 6040 Episode Num: 198 Episode_Length T: 23 Return: 0.000 ======
# ====== Total T: 6054 Episode Num: 199 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 6061 Episode Num: 200 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 6153 Episode Num: 201 Episode_Length T: 92 Return: 1.000 ======
# ====== Total T: 6172 Episode Num: 202 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 6218 Episode Num: 203 Episode_Length T: 46 Return: 0.000 ======
# ====== Total T: 6220 Episode Num: 204 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 6227 Episode Num: 205 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 6243 Episode Num: 206 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 6252 Episode Num: 207 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 6254 Episode Num: 208 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 6324 Episode Num: 209 Episode_Length T: 70 Return: 0.000 ======
# ====== Total T: 6346 Episode Num: 210 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 6480 Episode Num: 211 Episode_Length T: 134 Return: 0.000 ======
# ====== Total T: 6490 Episode Num: 212 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 6496 Episode Num: 213 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 6506 Episode Num: 214 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 6679 Episode Num: 215 Episode_Length T: 173 Return: 0.000 ======
# ====== Total T: 6708 Episode Num: 216 Episode_Length T: 29 Return: 0.000 ======
# ====== Total T: 6748 Episode Num: 217 Episode_Length T: 40 Return: 0.000 ======
# ====== Total T: 6804 Episode Num: 218 Episode_Length T: 56 Return: 0.000 ======
# ====== Total T: 6806 Episode Num: 219 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 6849 Episode Num: 220 Episode_Length T: 43 Return: 0.000 ======
# ====== Total T: 6856 Episode Num: 221 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 6922 Episode Num: 222 Episode_Length T: 66 Return: 0.000 ======
#   1%|          | 7395/1000000 [00:08<21:49, 758.13it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.500
# ---------------------------------------
# ====== Total T: 7075 Episode Num: 223 Episode_Length T: 153 Return: 2.000 ======
# ====== Total T: 7080 Episode Num: 224 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 7086 Episode Num: 225 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 7098 Episode Num: 226 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 7109 Episode Num: 227 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 7114 Episode Num: 228 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 7144 Episode Num: 229 Episode_Length T: 30 Return: 0.000 ======
# ====== Total T: 7166 Episode Num: 230 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 7179 Episode Num: 231 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 7192 Episode Num: 232 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 7213 Episode Num: 233 Episode_Length T: 21 Return: 0.000 ======
# ====== Total T: 7227 Episode Num: 234 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 7234 Episode Num: 235 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 7262 Episode Num: 236 Episode_Length T: 28 Return: 0.000 ======
# ====== Total T: 7313 Episode Num: 237 Episode_Length T: 51 Return: 0.000 ======
# ====== Total T: 7327 Episode Num: 238 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 7365 Episode Num: 239 Episode_Length T: 38 Return: 0.000 ======
# ====== Total T: 7397 Episode Num: 240 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 7404 Episode Num: 241 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 7470 Episode Num: 242 Episode_Length T: 66 Return: 0.000 ======
# ====== Total T: 7509 Episode Num: 243 Episode_Length T: 39 Return: 0.000 ======
# ====== Total T: 7575 Episode Num: 244 Episode_Length T: 66 Return: 0.000 ======
# ====== Total T: 7588 Episode Num: 245 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 7594 Episode Num: 246 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 7609 Episode Num: 247 Episode_Length T: 15 Return: 0.000 ======
# ====== Total T: 7614 Episode Num: 248 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 7622 Episode Num: 249 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 7741 Episode Num: 250 Episode_Length T: 119 Return: 1.000 ======
# ====== Total T: 7755 Episode Num: 251 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 7763 Episode Num: 252 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 7767 Episode Num: 253 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 7788 Episode Num: 254 Episode_Length T: 21 Return: 0.000 ======
# ====== Total T: 7804 Episode Num: 255 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 7810 Episode Num: 256 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 7830 Episode Num: 257 Episode_Length T: 20 Return: 0.000 ======
# ====== Total T: 7842 Episode Num: 258 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 7860 Episode Num: 259 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 7907 Episode Num: 260 Episode_Length T: 47 Return: 0.000 ======
# ====== Total T: 7915 Episode Num: 261 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 7925 Episode Num: 262 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 7963 Episode Num: 263 Episode_Length T: 38 Return: 0.000 ======
# ====== Total T: 7970 Episode Num: 264 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 7988 Episode Num: 265 Episode_Length T: 18 Return: 0.000 ======
#   1%|          | 8830/1000000 [00:09<14:32, 1135.84it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.300
# ---------------------------------------
# ====== Total T: 8023 Episode Num: 266 Episode_Length T: 35 Return: 0.000 ======
# ====== Total T: 8032 Episode Num: 267 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 8054 Episode Num: 268 Episode_Length T: 22 Return: 0.000 ======
# ====== Total T: 8086 Episode Num: 269 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 8094 Episode Num: 270 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 8105 Episode Num: 271 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 8165 Episode Num: 272 Episode_Length T: 60 Return: 1.000 ======
# ====== Total T: 8192 Episode Num: 273 Episode_Length T: 27 Return: 0.000 ======
# ====== Total T: 8204 Episode Num: 274 Episode_Length T: 12 Return: 0.000 ======
# ====== Total T: 8212 Episode Num: 275 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 8230 Episode Num: 276 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 8238 Episode Num: 277 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 8251 Episode Num: 278 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 8309 Episode Num: 279 Episode_Length T: 58 Return: 0.000 ======
# ====== Total T: 8320 Episode Num: 280 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 8337 Episode Num: 281 Episode_Length T: 17 Return: 0.000 ======
# ====== Total T: 8340 Episode Num: 282 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 8355 Episode Num: 283 Episode_Length T: 15 Return: 0.000 ======
# ====== Total T: 8364 Episode Num: 284 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 8369 Episode Num: 285 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 8376 Episode Num: 286 Episode_Length T: 7 Return: 0.000 ======
# ====== Total T: 8406 Episode Num: 287 Episode_Length T: 30 Return: 0.000 ======
# ====== Total T: 8445 Episode Num: 288 Episode_Length T: 39 Return: 0.000 ======
# ====== Total T: 8449 Episode Num: 289 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 8459 Episode Num: 290 Episode_Length T: 10 Return: 0.000 ======
# ====== Total T: 8465 Episode Num: 291 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 8522 Episode Num: 292 Episode_Length T: 57 Return: 0.000 ======
# ====== Total T: 8657 Episode Num: 293 Episode_Length T: 135 Return: 0.000 ======
# ====== Total T: 8661 Episode Num: 294 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 8685 Episode Num: 295 Episode_Length T: 24 Return: 0.000 ======
# ====== Total T: 8716 Episode Num: 296 Episode_Length T: 31 Return: 0.000 ======
# ====== Total T: 8806 Episode Num: 297 Episode_Length T: 90 Return: 0.000 ======
# ====== Total T: 8829 Episode Num: 298 Episode_Length T: 23 Return: 0.000 ======
# ====== Total T: 8885 Episode Num: 299 Episode_Length T: 56 Return: 1.000 ======
# ====== Total T: 8944 Episode Num: 300 Episode_Length T: 59 Return: 0.000 ======
# ====== Total T: 8978 Episode Num: 301 Episode_Length T: 34 Return: 0.000 ======
# ====== Total T: 8987 Episode Num: 302 Episode_Length T: 9 Return: 0.000 ======
#   1%|          | 9250/1000000 [00:09<19:18, 855.13it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.200
# ---------------------------------------
# ====== Total T: 9098 Episode Num: 303 Episode_Length T: 111 Return: 0.000 ======
# ====== Total T: 9124 Episode Num: 304 Episode_Length T: 26 Return: 0.000 ======
# ====== Total T: 9159 Episode Num: 305 Episode_Length T: 35 Return: 0.000 ======
# ====== Total T: 9170 Episode Num: 306 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 9207 Episode Num: 307 Episode_Length T: 37 Return: 0.000 ======
# ====== Total T: 9232 Episode Num: 308 Episode_Length T: 25 Return: 0.000 ======
# ====== Total T: 9243 Episode Num: 309 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 9247 Episode Num: 310 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 9266 Episode Num: 311 Episode_Length T: 19 Return: 0.000 ======
# ====== Total T: 9291 Episode Num: 312 Episode_Length T: 25 Return: 0.000 ======
# ====== Total T: 9319 Episode Num: 313 Episode_Length T: 28 Return: 0.000 ======
# ====== Total T: 9337 Episode Num: 314 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 9345 Episode Num: 315 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 9350 Episode Num: 316 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 9363 Episode Num: 317 Episode_Length T: 13 Return: 0.000 ======
# ====== Total T: 9464 Episode Num: 318 Episode_Length T: 101 Return: 1.000 ======
# ====== Total T: 9520 Episode Num: 319 Episode_Length T: 56 Return: 1.000 ======
# ====== Total T: 9642 Episode Num: 320 Episode_Length T: 122 Return: 0.000 ======
# ====== Total T: 9686 Episode Num: 321 Episode_Length T: 44 Return: 0.000 ======
# ====== Total T: 9702 Episode Num: 322 Episode_Length T: 16 Return: 0.000 ======
# ====== Total T: 9716 Episode Num: 323 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 9748 Episode Num: 324 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 9766 Episode Num: 325 Episode_Length T: 18 Return: 0.000 ======
# ====== Total T: 9771 Episode Num: 326 Episode_Length T: 5 Return: 0.000 ======
# ====== Total T: 9774 Episode Num: 327 Episode_Length T: 3 Return: 0.000 ======
# ====== Total T: 9788 Episode Num: 328 Episode_Length T: 14 Return: 0.000 ======
# ====== Total T: 9797 Episode Num: 329 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 9846 Episode Num: 330 Episode_Length T: 49 Return: 0.000 ======
# ====== Total T: 9881 Episode Num: 331 Episode_Length T: 35 Return: 0.000 ======
# ====== Total T: 9887 Episode Num: 332 Episode_Length T: 6 Return: 0.000 ======
# ====== Total T: 9896 Episode Num: 333 Episode_Length T: 9 Return: 0.000 ======
# ====== Total T: 9907 Episode Num: 334 Episode_Length T: 11 Return: 0.000 ======
# ====== Total T: 9985 Episode Num: 335 Episode_Length T: 78 Return: 0.000 ======
#   1%|          | 10000/1000000 [00:10<18:57, 870.63it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.000
# ---------------------------------------
# ====== Total T: 10012 Episode Num: 336 Episode_Length T: 27 Return: 0.000 ======
# /home/mila/y/yiran.wang/.conda/envs/mujoco_env/lib/python3.7/site-packages/ipykernel_launcher.py:396: UserWarning: Using a target size (torch.Size([256])) that is different to the input size (torch.Size([256, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# ====== Total T: 10129 Episode Num: 337 Episode_Length T: 117 Return: 2.000 ======
# ====== Total T: 10169 Episode Num: 338 Episode_Length T: 40 Return: 0.000 ======
# ====== Total T: 10171 Episode Num: 339 Episode_Length T: 2 Return: 0.000 ======
# ====== Total T: 10192 Episode Num: 340 Episode_Length T: 21 Return: 0.000 ======
# ====== Total T: 10198 Episode Num: 341 Episode_Length T: 6 Return: 0.000 ======
#   1%|          | 10414/1000000 [00:15<1:01:41, 267.33it/s]
# ====== Total T: 10396 Episode Num: 342 Episode_Length T: 198 Return: 2.000 ======
# ====== Total T: 10417 Episode Num: 343 Episode_Length T: 21 Return: 0.000 ======
#   1%|          | 10537/1000000 [00:17<1:16:10, 216.51it/s]
# ====== Total T: 10540 Episode Num: 344 Episode_Length T: 123 Return: 0.000 ======
# ====== Total T: 10561 Episode Num: 345 Episode_Length T: 21 Return: 0.000 ======
# ====== Total T: 10590 Episode Num: 346 Episode_Length T: 29 Return: 0.000 ======
#   1%|          | 10626/1000000 [00:18<1:28:37, 186.05it/s]
# ====== Total T: 10623 Episode Num: 347 Episode_Length T: 33 Return: 0.000 ======
# ====== Total T: 10663 Episode Num: 348 Episode_Length T: 40 Return: 0.000 ======
#   1%|          | 10691/1000000 [00:18<1:38:25, 167.53it/s]
# ====== Total T: 10682 Episode Num: 349 Episode_Length T: 19 Return: 0.000 ======
#   1%|          | 10739/1000000 [00:19<1:46:05, 155.42it/s]
# ====== Total T: 10731 Episode Num: 350 Episode_Length T: 49 Return: 1.000 ======
# ====== Total T: 10748 Episode Num: 351 Episode_Length T: 17 Return: 0.000 ======
#   1%|          | 10804/1000000 [00:20<2:00:46, 136.51it/s]
# ====== Total T: 10787 Episode Num: 352 Episode_Length T: 39 Return: 0.000 ======
#   1%|          | 10846/1000000 [00:20<2:14:55, 122.19it/s]
# ====== Total T: 10840 Episode Num: 353 Episode_Length T: 53 Return: 0.000 ======
#   1%|          | 10950/1000000 [00:21<2:57:37, 92.80it/s]
# ====== Total T: 10936 Episode Num: 354 Episode_Length T: 96 Return: 0.000 ======
# ====== Total T: 10948 Episode Num: 355 Episode_Length T: 12 Return: 0.000 ======
#   1%|          | 10990/1000000 [00:22<3:05:18, 88.95it/s]
# ====== Total T: 10984 Episode Num: 356 Episode_Length T: 36 Return: 0.000 ======
#   1%|          | 11010/1000000 [00:24<11:35:32, 23.70it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.600
# ---------------------------------------
# ====== Total T: 11009 Episode Num: 357 Episode_Length T: 25 Return: 0.000 ======
#   1%|          | 11040/1000000 [00:24<6:06:20, 44.99it/s]
# ====== Total T: 11026 Episode Num: 358 Episode_Length T: 17 Return: 0.000 ======
#   1%|          | 11090/1000000 [00:24<3:42:53, 73.95it/s]
# ====== Total T: 11083 Episode Num: 359 Episode_Length T: 57 Return: 0.000 ======
#   1%|          | 11180/1000000 [00:25<3:10:40, 86.43it/s]
# ====== Total T: 11166 Episode Num: 360 Episode_Length T: 83 Return: 1.000 ======
#   1%|          | 11200/1000000 [00:26<3:09:14, 87.09it/s]
# ====== Total T: 11189 Episode Num: 361 Episode_Length T: 23 Return: 0.000 ======
#   1%|          | 11272/1000000 [00:27<3:13:35, 85.12it/s]
# ====== Total T: 11255 Episode Num: 362 Episode_Length T: 66 Return: 0.000 ======
#   1%|          | 11300/1000000 [00:27<3:11:05, 86.23it/s]
# ====== Total T: 11288 Episode Num: 363 Episode_Length T: 33 Return: 0.000 ======
#   1%|          | 11340/1000000 [00:27<3:12:14, 85.71it/s]
# ====== Total T: 11326 Episode Num: 364 Episode_Length T: 38 Return: 0.000 ======
# ====== Total T: 11336 Episode Num: 365 Episode_Length T: 10 Return: 0.000 ======
#   1%|          | 11358/1000000 [00:28<3:14:12, 84.84it/s]
# ====== Total T: 11346 Episode Num: 366 Episode_Length T: 10 Return: 0.000 ======
#   1%|          | 11385/1000000 [00:28<3:15:18, 84.36it/s]
# ====== Total T: 11374 Episode Num: 367 Episode_Length T: 28 Return: 0.000 ======
#   1%|          | 11403/1000000 [00:28<3:14:52, 84.55it/s]
# ====== Total T: 11391 Episode Num: 368 Episode_Length T: 17 Return: 0.000 ======
#   1%|          | 11540/1000000 [00:30<3:10:01, 86.69it/s]
# ====== Total T: 11530 Episode Num: 369 Episode_Length T: 139 Return: 1.000 ======
# ====== Total T: 11546 Episode Num: 370 Episode_Length T: 16 Return: 0.000 ======
#   1%|          | 11576/1000000 [00:30<3:13:46, 85.02it/s]
# ====== Total T: 11560 Episode Num: 371 Episode_Length T: 14 Return: 0.000 ======
#   1%|          | 11651/1000000 [00:31<3:13:18, 85.22it/s]
# ====== Total T: 11640 Episode Num: 372 Episode_Length T: 80 Return: 1.000 ======
# ====== Total T: 11649 Episode Num: 373 Episode_Length T: 9 Return: 0.000 ======
#   1%|          | 11850/1000000 [00:33<3:09:45, 86.79it/s]
# ====== Total T: 11837 Episode Num: 374 Episode_Length T: 188 Return: 2.000 ======
# ====== Total T: 11846 Episode Num: 375 Episode_Length T: 9 Return: 0.000 ======
#   1%|          | 11895/1000000 [00:34<3:12:32, 85.53it/s]
# ====== Total T: 11887 Episode Num: 376 Episode_Length T: 41 Return: 0.000 ======
#   1%|          | 11945/1000000 [00:34<3:09:03, 87.10it/s]
# ====== Total T: 11933 Episode Num: 377 Episode_Length T: 46 Return: 0.000 ======
#   1%|          | 12010/1000000 [00:36<9:26:24, 29.07it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.800
# ---------------------------------------
# ====== Total T: 12005 Episode Num: 378 Episode_Length T: 72 Return: 1.000 ======
#   1%|          | 12040/1000000 [00:36<5:15:15, 52.23it/s]
# ====== Total T: 12032 Episode Num: 379 Episode_Length T: 27 Return: 0.000 ======
#   1%|          | 12080/1000000 [00:37<3:40:40, 74.61it/s]
# ====== Total T: 12071 Episode Num: 380 Episode_Length T: 39 Return: 0.000 ======
# ====== Total T: 12075 Episode Num: 381 Episode_Length T: 4 Return: 0.000 ======
#   1%|          | 12119/1000000 [00:37<3:17:21, 83.43it/s]
# ====== Total T: 12102 Episode Num: 382 Episode_Length T: 27 Return: 0.000 ======
#   1%|          | 12182/1000000 [00:38<3:15:43, 84.12it/s]
# ====== Total T: 12167 Episode Num: 383 Episode_Length T: 65 Return: 0.000 ======
#   1%|          | 12200/1000000 [00:38<3:11:59, 85.75it/s]
# ====== Total T: 12191 Episode Num: 384 Episode_Length T: 24 Return: 0.000 ======
#   1%|          | 12315/1000000 [00:40<3:09:30, 86.87it/s]
# ====== Total T: 12301 Episode Num: 385 Episode_Length T: 110 Return: 2.000 ======
#   1%|          | 12342/1000000 [00:40<3:14:48, 84.50it/s]
# ====== Total T: 12328 Episode Num: 386 Episode_Length T: 27 Return: 0.000 ======
#   1%|          | 12466/1000000 [00:41<3:11:27, 85.96it/s]
# ====== Total T: 12456 Episode Num: 387 Episode_Length T: 128 Return: 0.000 ======
# ====== Total T: 12472 Episode Num: 388 Episode_Length T: 16 Return: 0.000 ======
#   1%|          | 12495/1000000 [00:42<3:13:21, 85.12it/s]
# ====== Total T: 12486 Episode Num: 389 Episode_Length T: 14 Return: 0.000 ======
#   1%|▏         | 12544/1000000 [00:42<3:09:52, 86.68it/s]
# ====== Total T: 12530 Episode Num: 390 Episode_Length T: 44 Return: 0.000 ======
#   1%|▏         | 12562/1000000 [00:43<3:13:13, 85.17it/s]
# ====== Total T: 12548 Episode Num: 391 Episode_Length T: 18 Return: 0.000 ======
#   1%|▏         | 12691/1000000 [00:44<3:09:58, 86.62it/s]
# ====== Total T: 12677 Episode Num: 392 Episode_Length T: 129 Return: 1.000 ======
# ====== Total T: 12690 Episode Num: 393 Episode_Length T: 13 Return: 0.000 ======
#   1%|▏         | 12737/1000000 [00:45<3:13:23, 85.08it/s]
# ====== Total T: 12728 Episode Num: 394 Episode_Length T: 38 Return: 0.000 ======
#   1%|▏         | 12936/1000000 [00:47<3:17:06, 83.46it/s]
# ====== Total T: 12926 Episode Num: 395 Episode_Length T: 198 Return: 1.000 ======
#   1%|▏         | 12990/1000000 [00:48<3:15:56, 83.96it/s]
# ====== Total T: 12986 Episode Num: 396 Episode_Length T: 60 Return: 0.000 ======
#   1%|▏         | 13010/1000000 [00:49<7:26:26, 36.85it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.300
# ---------------------------------------
#   1%|▏         | 13130/1000000 [00:50<3:02:21, 90.19it/s]
# ====== Total T: 13114 Episode Num: 397 Episode_Length T: 128 Return: 0.000 ======
#   1%|▏         | 13150/1000000 [00:50<3:04:11, 89.29it/s]
# ====== Total T: 13143 Episode Num: 398 Episode_Length T: 29 Return: 0.000 ======
# ====== Total T: 13154 Episode Num: 399 Episode_Length T: 11 Return: 0.000 ======
#   1%|▏         | 13225/1000000 [00:51<3:06:55, 87.98it/s]
# ====== Total T: 13208 Episode Num: 400 Episode_Length T: 54 Return: 0.000 ======
# ====== Total T: 13216 Episode Num: 401 Episode_Length T: 8 Return: 0.000 ======
# ====== Total T: 13224 Episode Num: 402 Episode_Length T: 8 Return: 0.000 ======
#   1%|▏         | 13390/1000000 [00:53<3:12:01, 85.63it/s]
# ====== Total T: 13377 Episode Num: 403 Episode_Length T: 153 Return: 1.000 ======
#   1%|▏         | 13419/1000000 [00:53<3:09:20, 86.84it/s]
# ====== Total T: 13406 Episode Num: 404 Episode_Length T: 29 Return: 0.000 ======
# ====== Total T: 13422 Episode Num: 405 Episode_Length T: 16 Return: 0.000 ======
#   1%|▏         | 13465/1000000 [00:54<3:11:34, 85.83it/s]
# ====== Total T: 13451 Episode Num: 406 Episode_Length T: 29 Return: 0.000 ======
#   1%|▏         | 13697/1000000 [00:56<3:10:57, 86.09it/s]
# ====== Total T: 13687 Episode Num: 407 Episode_Length T: 236 Return: 5.000 ======
#   1%|▏         | 13755/1000000 [00:57<3:09:32, 86.72it/s]
# ====== Total T: 13744 Episode Num: 408 Episode_Length T: 57 Return: 0.000 ======
# ====== Total T: 13757 Episode Num: 409 Episode_Length T: 13 Return: 0.000 ======
#   1%|▏         | 13842/1000000 [00:58<3:10:06, 86.46it/s]
# ====== Total T: 13825 Episode Num: 410 Episode_Length T: 68 Return: 0.000 ======
#   1%|▏         | 13897/1000000 [00:59<3:13:49, 84.80it/s]
# ====== Total T: 13885 Episode Num: 411 Episode_Length T: 60 Return: 0.000 ======
#   1%|▏         | 13915/1000000 [00:59<3:16:39, 83.57it/s]
# ====== Total T: 13903 Episode Num: 412 Episode_Length T: 18 Return: 0.000 ======
#   1%|▏         | 14016/1000000 [01:02<12:08:37, 22.55it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.600
# ---------------------------------------
#   1%|▏         | 14156/1000000 [01:03<3:13:55, 84.73it/s]
# ====== Total T: 14140 Episode Num: 413 Episode_Length T: 237 Return: 1.000 ======
#   1%|▏         | 14296/1000000 [01:05<3:20:06, 82.10it/s]
# ====== Total T: 14288 Episode Num: 414 Episode_Length T: 148 Return: 1.000 ======
# ====== Total T: 14291 Episode Num: 415 Episode_Length T: 3 Return: 0.000 ======
#   1%|▏         | 14446/1000000 [01:07<3:11:24, 85.81it/s]
# ====== Total T: 14431 Episode Num: 416 Episode_Length T: 140 Return: 1.000 ======
#   1%|▏         | 14657/1000000 [01:09<3:16:05, 83.75it/s]
# ====== Total T: 14644 Episode Num: 417 Episode_Length T: 213 Return: 3.000 ======
#   1%|▏         | 14675/1000000 [01:09<3:11:48, 85.62it/s]
# ====== Total T: 14665 Episode Num: 418 Episode_Length T: 21 Return: 0.000 ======
#   1%|▏         | 14761/1000000 [01:10<3:04:58, 88.77it/s]
# ====== Total T: 14751 Episode Num: 419 Episode_Length T: 86 Return: 0.000 ======
# ====== Total T: 14766 Episode Num: 420 Episode_Length T: 15 Return: 0.000 ======
#   1%|▏         | 14800/1000000 [01:11<3:08:16, 87.21it/s]
# ====== Total T: 14786 Episode Num: 421 Episode_Length T: 20 Return: 0.000 ======
#   1%|▏         | 14883/1000000 [01:12<3:12:03, 85.49it/s]
# ====== Total T: 14874 Episode Num: 422 Episode_Length T: 88 Return: 0.000 ======
#   1%|▏         | 14930/1000000 [01:12<3:10:55, 85.99it/s]
# ====== Total T: 14913 Episode Num: 423 Episode_Length T: 39 Return: 0.000 ======
#   1%|▏         | 14957/1000000 [01:12<3:13:28, 84.85it/s]
# ====== Total T: 14940 Episode Num: 424 Episode_Length T: 27 Return: 0.000 ======
#   1%|▏         | 14993/1000000 [01:13<3:15:58, 83.77it/s]
# ====== Total T: 14984 Episode Num: 425 Episode_Length T: 44 Return: 0.000 ======
# ====== Total T: 14992 Episode Num: 426 Episode_Length T: 8 Return: 0.000 ======
#   2%|▏         | 15011/1000000 [01:14<11:23:31, 24.02it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.300
# ---------------------------------------
#   2%|▏         | 15115/1000000 [01:16<3:25:22, 79.93it/s]
# ====== Total T: 15102 Episode Num: 427 Episode_Length T: 110 Return: 2.000 ======
#   2%|▏         | 15182/1000000 [01:16<3:17:16, 83.20it/s]
# ====== Total T: 15173 Episode Num: 428 Episode_Length T: 71 Return: 0.000 ======
#   2%|▏         | 15305/1000000 [01:18<3:11:30, 85.69it/s]
# ====== Total T: 15289 Episode Num: 429 Episode_Length T: 116 Return: 0.000 ======
#   2%|▏         | 15410/1000000 [01:19<3:13:12, 84.94it/s]
# ====== Total T: 15397 Episode Num: 430 Episode_Length T: 108 Return: 1.000 ======
#   2%|▏         | 15457/1000000 [01:20<3:11:44, 85.58it/s]
# ====== Total T: 15444 Episode Num: 431 Episode_Length T: 47 Return: 1.000 ======
# ====== Total T: 15447 Episode Num: 432 Episode_Length T: 3 Return: 0.000 ======
#   2%|▏         | 15495/1000000 [01:20<3:09:28, 86.60it/s]
# ====== Total T: 15485 Episode Num: 433 Episode_Length T: 38 Return: 0.000 ======
#   2%|▏         | 15614/1000000 [01:21<3:08:17, 87.13it/s]
# ====== Total T: 15597 Episode Num: 434 Episode_Length T: 112 Return: 0.000 ======
#   2%|▏         | 15659/1000000 [01:22<3:10:38, 86.06it/s]
# ====== Total T: 15643 Episode Num: 435 Episode_Length T: 46 Return: 0.000 ======
#   2%|▏         | 15686/1000000 [01:22<3:14:11, 84.48it/s]
# ====== Total T: 15678 Episode Num: 436 Episode_Length T: 35 Return: 0.000 ======
#   2%|▏         | 15735/1000000 [01:23<3:10:52, 85.94it/s]
# ====== Total T: 15718 Episode Num: 437 Episode_Length T: 40 Return: 0.000 ======
#   2%|▏         | 15865/1000000 [01:24<3:12:04, 85.40it/s]
# ====== Total T: 15851 Episode Num: 438 Episode_Length T: 133 Return: 1.000 ======
#   2%|▏         | 15915/1000000 [01:25<3:08:47, 86.87it/s]
# ====== Total T: 15899 Episode Num: 439 Episode_Length T: 48 Return: 0.000 ======
#   2%|▏         | 15942/1000000 [01:25<3:13:21, 84.83it/s]
# ====== Total T: 15934 Episode Num: 440 Episode_Length T: 35 Return: 0.000 ======
#   2%|▏         | 15980/1000000 [01:26<3:12:34, 85.16it/s]
# ====== Total T: 15963 Episode Num: 441 Episode_Length T: 29 Return: 0.000 ======
#   2%|▏         | 16010/1000000 [01:27<10:45:13, 25.42it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.400
# ---------------------------------------
#   2%|▏         | 16080/1000000 [01:28<3:45:46, 72.63it/s]
# ====== Total T: 16065 Episode Num: 442 Episode_Length T: 102 Return: 1.000 ======
#   2%|▏         | 16145/1000000 [01:29<3:13:55, 84.55it/s]
# ====== Total T: 16137 Episode Num: 443 Episode_Length T: 72 Return: 0.000 ======
#   2%|▏         | 16202/1000000 [01:30<3:10:28, 86.08it/s]
# ====== Total T: 16191 Episode Num: 444 Episode_Length T: 54 Return: 0.000 ======
#   2%|▏         | 16260/1000000 [01:30<3:09:27, 86.54it/s]
# ====== Total T: 16247 Episode Num: 445 Episode_Length T: 56 Return: 0.000 ======
#   2%|▏         | 16355/1000000 [01:31<3:06:51, 87.74it/s]
# ====== Total T: 16337 Episode Num: 446 Episode_Length T: 90 Return: 1.000 ======
#   2%|▏         | 16373/1000000 [01:32<3:08:22, 87.03it/s]
# ====== Total T: 16358 Episode Num: 447 Episode_Length T: 21 Return: 0.000 ======
#   2%|▏         | 16400/1000000 [01:32<3:08:53, 86.79it/s]
# ====== Total T: 16391 Episode Num: 448 Episode_Length T: 33 Return: 0.000 ======
#   2%|▏         | 16440/1000000 [01:32<3:10:15, 86.16it/s]
# ====== Total T: 16424 Episode Num: 449 Episode_Length T: 33 Return: 0.000 ======
#   2%|▏         | 16550/1000000 [01:34<3:10:24, 86.08it/s]
# ====== Total T: 16543 Episode Num: 450 Episode_Length T: 119 Return: 0.000 ======
#   2%|▏         | 16713/1000000 [01:36<3:14:13, 84.38it/s]
# ====== Total T: 16698 Episode Num: 451 Episode_Length T: 155 Return: 3.000 ======
#   2%|▏         | 16845/1000000 [01:37<3:08:45, 86.81it/s]
# ====== Total T: 16834 Episode Num: 452 Episode_Length T: 136 Return: 1.000 ======
#   2%|▏         | 16872/1000000 [01:37<3:09:01, 86.68it/s]
# ====== Total T: 16858 Episode Num: 453 Episode_Length T: 24 Return: 0.000 ======
# ====== Total T: 16872 Episode Num: 454 Episode_Length T: 14 Return: 0.000 ======
#   2%|▏         | 16966/1000000 [01:38<3:10:39, 85.93it/s]
# ====== Total T: 16958 Episode Num: 455 Episode_Length T: 86 Return: 1.000 ======
#   2%|▏         | 17012/1000000 [01:40<10:07:03, 26.99it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.400
# ---------------------------------------
#   2%|▏         | 17030/1000000 [01:40<6:38:10, 41.15it/s]
# ====== Total T: 17022 Episode Num: 456 Episode_Length T: 64 Return: 1.000 ======
#   2%|▏         | 17070/1000000 [01:41<3:54:30, 69.86it/s]
# ====== Total T: 17054 Episode Num: 457 Episode_Length T: 32 Return: 0.000 ======
# ====== Total T: 17058 Episode Num: 458 Episode_Length T: 4 Return: 0.000 ======
# ====== Total T: 17062 Episode Num: 459 Episode_Length T: 4 Return: 0.000 ======
#   2%|▏         | 17115/1000000 [01:41<3:20:01, 81.90it/s]
# ====== Total T: 17098 Episode Num: 460 Episode_Length T: 36 Return: 0.000 ======
#   2%|▏         | 17207/1000000 [01:42<3:17:46, 82.82it/s]
# ====== Total T: 17191 Episode Num: 461 Episode_Length T: 93 Return: 1.000 ======
#   2%|▏         | 17225/1000000 [01:43<3:15:14, 83.89it/s]
# ====== Total T: 17213 Episode Num: 462 Episode_Length T: 22 Return: 0.000 ======
#   2%|▏         | 17329/1000000 [01:44<3:08:15, 87.00it/s]
# ====== Total T: 17317 Episode Num: 463 Episode_Length T: 104 Return: 1.000 ======
#   2%|▏         | 17402/1000000 [01:45<3:19:50, 81.95it/s]
# ====== Total T: 17389 Episode Num: 464 Episode_Length T: 72 Return: 0.000 ======
#   2%|▏         | 17520/1000000 [01:46<3:14:45, 84.08it/s]
# ====== Total T: 17510 Episode Num: 465 Episode_Length T: 121 Return: 2.000 ======
#   2%|▏         | 17548/1000000 [01:46<3:14:48, 84.05it/s]
# ====== Total T: 17535 Episode Num: 466 Episode_Length T: 25 Return: 0.000 ======
#   2%|▏         | 17620/1000000 [01:47<3:11:47, 85.37it/s]
# ====== Total T: 17609 Episode Num: 467 Episode_Length T: 74 Return: 0.000 ======
# ====== Total T: 17616 Episode Num: 468 Episode_Length T: 7 Return: 0.000 ======
#   2%|▏         | 17805/1000000 [01:49<3:11:01, 85.70it/s]
# ====== Total T: 17797 Episode Num: 469 Episode_Length T: 181 Return: 2.000 ======
# ====== Total T: 17807 Episode Num: 470 Episode_Length T: 10 Return: 0.000 ======
#   2%|▏         | 17855/1000000 [01:50<3:07:17, 87.40it/s]
# ====== Total T: 17842 Episode Num: 471 Episode_Length T: 35 Return: 0.000 ======
#   2%|▏         | 17882/1000000 [01:50<3:11:37, 85.42it/s]
# ====== Total T: 17865 Episode Num: 472 Episode_Length T: 23 Return: 0.000 ======
#   2%|▏         | 17995/1000000 [01:52<3:06:09, 87.92it/s]
# ====== Total T: 17988 Episode Num: 473 Episode_Length T: 123 Return: 1.000 ======
# ====== Total T: 17993 Episode Num: 474 Episode_Length T: 5 Return: 0.000 ======
#   2%|▏         | 18012/1000000 [01:53<10:43:25, 25.44it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.600
# ---------------------------------------
#   2%|▏         | 18060/1000000 [01:54<4:20:40, 62.78it/s]
# ====== Total T: 18050 Episode Num: 475 Episode_Length T: 57 Return: 0.000 ======
#   2%|▏         | 18297/1000000 [01:56<3:14:37, 84.06it/s]
# ====== Total T: 18287 Episode Num: 476 Episode_Length T: 237 Return: 3.000 ======
#   2%|▏         | 18365/1000000 [01:57<3:07:23, 87.31it/s]
# ====== Total T: 18349 Episode Num: 477 Episode_Length T: 62 Return: 0.000 ======
#   2%|▏         | 18421/1000000 [01:58<3:25:26, 79.63it/s]
# ====== Total T: 18408 Episode Num: 478 Episode_Length T: 59 Return: 0.000 ======
#   2%|▏         | 18450/1000000 [01:58<3:16:12, 83.38it/s]
# ...
# ---------------------------------------
# Evaluation over 10 episodes: 0.300
# ---------------------------------------
#  49%|████▉     | 493075/1000000 [1:52:05<2:04:00, 68.13it/s]
# ====== Total T: 493064 Episode Num: 5275 Episode_Length T: 218 Return: 4.000 ======
#  49%|████▉     | 493346/1000000 [1:52:09<1:48:41, 77.68it/s]
# ====== Total T: 493338 Episode Num: 5276 Episode_Length T: 274 Return: 2.000 ======
#  49%|████▉     | 493373/1000000 [1:52:09<1:45:29, 80.04it/s]
# ====== Total T: 493360 Episode Num: 5277 Episode_Length T: 22 Return: 0.000 ======
#  49%|████▉     | 493490/1000000 [1:52:11<1:44:38, 80.68it/s]
# ====== Total T: 493481 Episode Num: 5278 Episode_Length T: 121 Return: 1.000 ======
#  49%|████▉     | 493598/1000000 [1:52:12<1:43:53, 81.24it/s]
# ====== Total T: 493582 Episode Num: 5279 Episode_Length T: 101 Return: 0.000 ======
#  49%|████▉     | 493798/1000000 [1:52:14<1:42:30, 82.30it/s]
# ====== Total T: 493784 Episode Num: 5280 Episode_Length T: 202 Return: 2.000 ======
#  49%|████▉     | 493926/1000000 [1:52:16<1:42:06, 82.61it/s]
# ====== Total T: 493918 Episode Num: 5281 Episode_Length T: 134 Return: 0.000 ======
#  49%|████▉     | 494016/1000000 [1:52:19<6:40:42, 21.05it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.900
# ---------------------------------------
#  49%|████▉     | 494131/1000000 [1:52:20<1:48:10, 77.94it/s]
# ====== Total T: 494124 Episode Num: 5282 Episode_Length T: 206 Return: 2.000 ======
#  49%|████▉     | 494260/1000000 [1:52:22<1:38:12, 85.82it/s]
# ====== Total T: 494251 Episode Num: 5283 Episode_Length T: 127 Return: 0.000 ======
#  49%|████▉     | 494541/1000000 [1:52:25<1:45:45, 79.65it/s]
# ====== Total T: 494528 Episode Num: 5284 Episode_Length T: 277 Return: 2.000 ======
#  49%|████▉     | 494622/1000000 [1:52:26<1:44:37, 80.51it/s]
# ====== Total T: 494609 Episode Num: 5285 Episode_Length T: 81 Return: 0.000 ======
#  49%|████▉     | 494713/1000000 [1:52:27<1:43:18, 81.52it/s]
# ====== Total T: 494698 Episode Num: 5286 Episode_Length T: 89 Return: 0.000 ======
#  49%|████▉     | 494785/1000000 [1:52:28<1:45:06, 80.11it/s]
# ====== Total T: 494770 Episode Num: 5287 Episode_Length T: 72 Return: 0.000 ======
#  49%|████▉     | 494859/1000000 [1:52:29<1:40:01, 84.18it/s]
# ====== Total T: 494851 Episode Num: 5288 Episode_Length T: 81 Return: 1.000 ======
#  50%|████▉     | 495012/1000000 [1:52:32<4:48:23, 29.18it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.400
# ---------------------------------------
# ====== Total T: 495015 Episode Num: 5289 Episode_Length T: 164 Return: 1.000 ======
#  50%|████▉     | 495162/1000000 [1:52:34<1:45:23, 79.84it/s]
# ====== Total T: 495149 Episode Num: 5290 Episode_Length T: 134 Return: 1.000 ======
#  50%|████▉     | 495235/1000000 [1:52:34<1:43:44, 81.09it/s]
# ====== Total T: 495227 Episode Num: 5291 Episode_Length T: 78 Return: 0.000 ======
#  50%|████▉     | 495273/1000000 [1:52:35<1:40:35, 83.63it/s]
# ====== Total T: 495262 Episode Num: 5292 Episode_Length T: 35 Return: 0.000 ======
#  50%|████▉     | 495420/1000000 [1:52:37<1:43:04, 81.59it/s]
# ====== Total T: 495408 Episode Num: 5293 Episode_Length T: 146 Return: 0.000 ======
#  50%|████▉     | 495474/1000000 [1:52:37<1:41:01, 83.23it/s]
# ====== Total T: 495463 Episode Num: 5294 Episode_Length T: 55 Return: 0.000 ======
#  50%|████▉     | 495674/1000000 [1:52:40<1:40:40, 83.49it/s]
# ====== Total T: 495665 Episode Num: 5295 Episode_Length T: 202 Return: 1.000 ======
#  50%|████▉     | 495893/1000000 [1:52:42<1:41:32, 82.75it/s]
# ====== Total T: 495876 Episode Num: 5296 Episode_Length T: 211 Return: 0.000 ======
# ====== Total T: 495889 Episode Num: 5297 Episode_Length T: 13 Return: 0.000 ======
#  50%|████▉     | 495947/1000000 [1:52:43<1:42:40, 81.82it/s]
# ====== Total T: 495933 Episode Num: 5298 Episode_Length T: 44 Return: 0.000 ======
#  50%|████▉     | 496010/1000000 [1:52:44<3:27:59, 40.39it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.100
# ---------------------------------------
#  50%|████▉     | 496091/1000000 [1:52:45<1:48:24, 77.47it/s]
# ====== Total T: 496076 Episode Num: 5299 Episode_Length T: 143 Return: 0.000 ======
#  50%|████▉     | 496118/1000000 [1:52:46<1:45:17, 79.76it/s]
# ====== Total T: 496102 Episode Num: 5300 Episode_Length T: 26 Return: 0.000 ======
# ====== Total T: 496106 Episode Num: 5301 Episode_Length T: 4 Return: 0.000 ======
#  50%|████▉     | 496172/1000000 [1:52:46<1:43:47, 80.91it/s]
# ====== Total T: 496161 Episode Num: 5302 Episode_Length T: 55 Return: 0.000 ======
#  50%|████▉     | 496245/1000000 [1:52:47<1:43:49, 80.86it/s]
# ====== Total T: 496235 Episode Num: 5303 Episode_Length T: 74 Return: 0.000 ======
#  50%|████▉     | 496281/1000000 [1:52:48<1:43:31, 81.09it/s]
# ====== Total T: 496268 Episode Num: 5304 Episode_Length T: 33 Return: 0.000 ======
#  50%|████▉     | 496397/1000000 [1:52:49<1:46:18, 78.95it/s]
# ====== Total T: 496389 Episode Num: 5305 Episode_Length T: 121 Return: 1.000 ======
#  50%|████▉     | 496424/1000000 [1:52:49<1:41:49, 82.43it/s]
# ====== Total T: 496412 Episode Num: 5306 Episode_Length T: 23 Return: 0.000 ======
#  50%|████▉     | 496486/1000000 [1:52:50<1:48:07, 77.61it/s]
# ====== Total T: 496476 Episode Num: 5307 Episode_Length T: 64 Return: 2.000 ======
#  50%|████▉     | 496539/1000000 [1:52:51<1:42:53, 81.56it/s]
# ====== Total T: 496524 Episode Num: 5308 Episode_Length T: 48 Return: 0.000 ======
#  50%|████▉     | 496865/1000000 [1:52:55<1:38:33, 85.08it/s]
# ====== Total T: 496857 Episode Num: 5309 Episode_Length T: 333 Return: 2.000 ======
# ====== Total T: 496866 Episode Num: 5310 Episode_Length T: 9 Return: 0.000 ======
#  50%|████▉     | 496932/1000000 [1:52:56<1:40:17, 83.60it/s]
# ====== Total T: 496916 Episode Num: 5311 Episode_Length T: 50 Return: 0.000 ======
#  50%|████▉     | 496990/1000000 [1:52:56<1:38:44, 84.91it/s]
# ====== Total T: 496988 Episode Num: 5312 Episode_Length T: 72 Return: 0.000 ======
#  50%|████▉     | 497010/1000000 [1:52:58<5:26:17, 25.69it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.400
# ---------------------------------------
#  50%|████▉     | 497044/1000000 [1:52:58<2:45:18, 50.71it/s]
# ====== Total T: 497030 Episode Num: 5313 Episode_Length T: 42 Return: 0.000 ======
#  50%|████▉     | 497254/1000000 [1:53:01<1:42:35, 81.67it/s]
# ====== Total T: 497244 Episode Num: 5314 Episode_Length T: 214 Return: 2.000 ======
#  50%|████▉     | 497457/1000000 [1:53:04<1:49:42, 76.35it/s]
# ====== Total T: 497447 Episode Num: 5315 Episode_Length T: 203 Return: 2.000 ======
#  50%|████▉     | 497524/1000000 [1:53:05<1:44:32, 80.10it/s]
# ====== Total T: 497508 Episode Num: 5316 Episode_Length T: 61 Return: 0.000 ======
#  50%|████▉     | 497634/1000000 [1:53:06<1:44:55, 79.80it/s]
# ====== Total T: 497618 Episode Num: 5317 Episode_Length T: 110 Return: 0.000 ======
#  50%|████▉     | 497713/1000000 [1:53:07<1:45:45, 79.16it/s]
# ====== Total T: 497704 Episode Num: 5318 Episode_Length T: 86 Return: 0.000 ======
#  50%|████▉     | 497767/1000000 [1:53:08<1:42:24, 81.73it/s]
# ====== Total T: 497757 Episode Num: 5319 Episode_Length T: 53 Return: 0.000 ======
#  50%|████▉     | 497871/1000000 [1:53:09<1:47:51, 77.59it/s]
# ====== Total T: 497863 Episode Num: 5320 Episode_Length T: 106 Return: 0.000 ======
#  50%|████▉     | 497933/1000000 [1:53:10<1:44:32, 80.04it/s]
# ====== Total T: 497922 Episode Num: 5321 Episode_Length T: 59 Return: 0.000 ======
#  50%|████▉     | 498010/1000000 [1:53:12<6:52:40, 20.27it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.100
# ---------------------------------------
#  50%|████▉     | 498137/1000000 [1:53:14<1:49:44, 76.22it/s]
# ====== Total T: 498126 Episode Num: 5322 Episode_Length T: 204 Return: 1.000 ======
#  50%|████▉     | 498267/1000000 [1:53:16<1:47:28, 77.80it/s]
# ====== Total T: 498252 Episode Num: 5323 Episode_Length T: 126 Return: 0.000 ======
#  50%|████▉     | 498293/1000000 [1:53:16<1:44:19, 80.15it/s]
# ====== Total T: 498279 Episode Num: 5324 Episode_Length T: 27 Return: 0.000 ======
#  50%|████▉     | 498409/1000000 [1:53:17<1:44:36, 79.92it/s]
# ====== Total T: 498395 Episode Num: 5325 Episode_Length T: 116 Return: 0.000 ======
#  50%|████▉     | 498470/1000000 [1:53:18<1:47:19, 77.88it/s]
# ====== Total T: 498460 Episode Num: 5326 Episode_Length T: 65 Return: 0.000 ======
#  50%|████▉     | 498530/1000000 [1:53:19<1:46:27, 78.51it/s]
# ====== Total T: 498516 Episode Num: 5327 Episode_Length T: 56 Return: 0.000 ======
#  50%|████▉     | 498591/1000000 [1:53:20<1:46:02, 78.80it/s]
# ====== Total T: 498581 Episode Num: 5328 Episode_Length T: 65 Return: 0.000 ======
#  50%|████▉     | 498696/1000000 [1:53:21<1:45:01, 79.55it/s]
# ====== Total T: 498683 Episode Num: 5329 Episode_Length T: 102 Return: 0.000 ======
#  50%|████▉     | 498731/1000000 [1:53:21<1:48:32, 76.97it/s]
# ====== Total T: 498723 Episode Num: 5330 Episode_Length T: 40 Return: 1.000 ======
#  50%|████▉     | 498851/1000000 [1:53:23<1:49:03, 76.58it/s]
# ====== Total T: 498844 Episode Num: 5331 Episode_Length T: 121 Return: 1.000 ======
#  50%|████▉     | 498980/1000000 [1:53:25<1:48:03, 77.27it/s]
# ====== Total T: 498965 Episode Num: 5332 Episode_Length T: 121 Return: 1.000 ======
#  50%|████▉     | 499013/1000000 [1:53:26<5:52:07, 23.71it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.600
# ---------------------------------------
#  50%|████▉     | 499030/1000000 [1:53:26<3:48:14, 36.58it/s]
# ====== Total T: 499016 Episode Num: 5333 Episode_Length T: 51 Return: 0.000 ======
#  50%|████▉     | 499195/1000000 [1:53:29<1:52:08, 74.43it/s]
# ====== Total T: 499187 Episode Num: 5334 Episode_Length T: 171 Return: 0.000 ======
#  50%|████▉     | 499401/1000000 [1:53:31<1:51:19, 74.95it/s]
# ====== Total T: 499389 Episode Num: 5335 Episode_Length T: 202 Return: 0.000 ======
#  50%|████▉     | 499576/1000000 [1:53:34<1:51:36, 74.73it/s]
# ====== Total T: 499564 Episode Num: 5336 Episode_Length T: 175 Return: 0.000 ======
#  50%|████▉     | 499744/1000000 [1:53:36<1:48:50, 76.60it/s]
# ====== Total T: 499736 Episode Num: 5337 Episode_Length T: 172 Return: 2.000 ======
#  50%|████▉     | 499801/1000000 [1:53:37<1:51:36, 74.69it/s]
# ====== Total T: 499791 Episode Num: 5338 Episode_Length T: 55 Return: 0.000 ======
#  50%|████▉     | 499902/1000000 [1:53:38<1:48:37, 76.74it/s]
# ====== Total T: 499890 Episode Num: 5339 Episode_Length T: 99 Return: 0.000 ======
#  50%|█████     | 500009/1000000 [1:53:41<5:41:56, 24.37it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.300
# ---------------------------------------
#  50%|█████     | 500109/1000000 [1:53:42<1:48:45, 76.61it/s]
# ====== Total T: 500101 Episode Num: 5340 Episode_Length T: 211 Return: 2.000 ======
#  50%|█████     | 500209/1000000 [1:53:43<1:43:14, 80.68it/s]
# ====== Total T: 500196 Episode Num: 5341 Episode_Length T: 95 Return: 0.000 ======
#  50%|█████     | 500279/1000000 [1:53:44<1:43:25, 80.53it/s]
# ====== Total T: 500269 Episode Num: 5342 Episode_Length T: 73 Return: 0.000 ======
#  50%|█████     | 500347/1000000 [1:53:45<1:49:08, 76.30it/s]
# ====== Total T: 500340 Episode Num: 5343 Episode_Length T: 71 Return: 0.000 ======
#  50%|█████     | 500555/1000000 [1:53:48<1:45:09, 79.16it/s]
# ====== Total T: 500542 Episode Num: 5344 Episode_Length T: 202 Return: 0.000 ======
#  50%|█████     | 500616/1000000 [1:53:48<1:48:31, 76.69it/s]
# ====== Total T: 500607 Episode Num: 5345 Episode_Length T: 65 Return: 0.000 ======
#  50%|█████     | 500738/1000000 [1:53:50<1:45:00, 79.24it/s]
# ====== Total T: 500726 Episode Num: 5346 Episode_Length T: 119 Return: 0.000 ======
#  50%|█████     | 500790/1000000 [1:53:51<1:47:26, 77.44it/s]
# ====== Total T: 500780 Episode Num: 5347 Episode_Length T: 54 Return: 0.000 ======
#  50%|█████     | 501015/1000000 [1:53:55<6:09:26, 22.51it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.400
# ---------------------------------------
#  50%|█████     | 501065/1000000 [1:53:55<2:16:13, 61.05it/s]
# ====== Total T: 501056 Episode Num: 5348 Episode_Length T: 276 Return: 1.000 ======
#  50%|█████     | 501283/1000000 [1:53:58<1:57:06, 70.98it/s]
# ====== Total T: 501268 Episode Num: 5349 Episode_Length T: 212 Return: 3.000 ======
#  50%|█████     | 501458/1000000 [1:54:01<1:50:05, 75.47it/s]
# ====== Total T: 501449 Episode Num: 5350 Episode_Length T: 181 Return: 0.000 ======
#  50%|█████     | 501525/1000000 [1:54:02<1:49:46, 75.69it/s]
# ====== Total T: 501513 Episode Num: 5351 Episode_Length T: 64 Return: 0.000 ======
#  50%|█████     | 501750/1000000 [1:54:05<1:51:29, 74.48it/s]
# ====== Total T: 501736 Episode Num: 5352 Episode_Length T: 223 Return: 2.000 ======
#  50%|█████     | 501808/1000000 [1:54:05<1:49:56, 75.52it/s]
# ====== Total T: 501798 Episode Num: 5353 Episode_Length T: 62 Return: 0.000 ======
#  50%|█████     | 501883/1000000 [1:54:06<1:48:50, 76.28it/s]
# ====== Total T: 501874 Episode Num: 5354 Episode_Length T: 76 Return: 0.000 ======
#  50%|█████     | 501966/1000000 [1:54:08<1:53:27, 73.16it/s]
# ====== Total T: 501952 Episode Num: 5355 Episode_Length T: 78 Return: 1.000 ======
#  50%|█████     | 502009/1000000 [1:54:10<6:46:45, 20.40it/s]
# ---------------------------------------
# Evaluation over 10 episodes: 0.500
# ---------------------------------------
#  50%|█████     | 502072/1000000 [1:54:10<2:14:31, 61.69it/s]
# ====== Total T: 502065 Episode Num: 5356 Episode_Length T: 113 Return: 1.000 ======
#  50%|█████     | 502263/1000000 [1:54:13<1:50:13, 75.26it/s]
# ====== Total T: 502251 Episode Num: 5357 Episode_Length T: 186 Return: 0.000 ======
#  50%|█████     | 502328/1000000 [1:54:14<1:50:31, 75.05it/s]
# ====== Total T: 502314 Episode Num: 5358 Episode_Length T: 63 Return: 0.000 ======
# ====== Total T: 502329 Episode Num: 5359 Episode_Length T: 15 Return: 0.000 ======
#  50%|█████     | 502577/1000000 [1:54:17<1:53:11, 73.24it/s]
# ====== Total T: 502562 Episode Num: 5360 Episode_Length T: 233 Return: 2.000 ======
#  50%|█████     | 502581/1000000 [1:54:17<1:53:07, 73.29it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_54377/2478764049.py in <module>
#       5     learning_start=int(1e4),
#       6     batch_size=32,
# ----> 7     fine_tune=True
#       8 )
#
# /tmp/ipykernel_54377/2005752785.py in learn(self, replay_buffer, step_size, learning_start, batch_size, fine_tune, log_freq)
#     424             replay_buffer.add(state, action, next_state, reward, done, task.cpu().data.numpy())
#     425             if replay_buffer.crt_size > learning_start:
# --> 426                 self.train(replay_buffer, batch_size=batch_size, fine_tune=fine_tune)
#     427
#     428             # update iterative values
#
# /tmp/ipykernel_54377/2005752785.py in train(self, replay_buffer, batch_size, fine_tune)
#     367         self.critic_opt.zero_grad()
#     368         Q_loss.backward()
# --> 369         self.critic_opt.step()
#     370
#     371         # train the task
#
# ~/.conda/envs/mujoco_env/lib/python3.7/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# ~/.conda/envs/mujoco_env/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#     117                    group['lr'],
#     118                    group['weight_decay'],
# --> 119                    group['eps']
#     120                    )
#     121         return loss
#
# ~/.conda/envs/mujoco_env/lib/python3.7/site-packages/torch/optim/functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      92             denom = (max_exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      93         else:
# ---> 94             denom = (exp_avg_sq.sqrt() / math.sqrt(bias_correction2)).add_(eps)
#      95
#      96         step_size = lr / bias_correction1
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

plt.plot(evaluations)
plt.title('aps fourrooms, conv encoder, layout=4rooms')
# Out:
# Text(0.5, 1.0, 'aps fourrooms, conv encoder, layout=4rooms')

# %%
import matplotlib.pyplot as plt

plt.plot(evaluations)
plt.title('aps fourrooms, conv encoder, layout=open')
# Out:
# Text(0.5, 1.0, 'aps fourrooms, conv encoder, layout=open')

# %%
import matplotlib.pyplot as plt

plt.plot(evaluations, title='aps after pretraini')
